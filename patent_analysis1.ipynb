# %%
from nltk.stem import WordNetLemmatizer
import nltk
import string
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')

remove_punct_dict = dict((ord(punct), None) for punct in string.punctuation)
lemmar = WordNetLemmatizer()

def LemTokens(tokens):
    return [lemmar.lemmatize(token) for token in tokens]

def LemNormalize(text):
    return LemTokens(nltk.word_tokenize(text.lower().translate(remove_punct_dict)))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Beck\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Beck\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Beck\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Beck\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Beck\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import pandas as pd
import glob, os
from sklearn.feature_extraction.text import TfidfVectorizer
patent=pd.read_csv('./patent2021_01.csv', low_memory=False)
tfidf_vect=TfidfVectorizer(tokenizer=LemNormalize, stop_words='english', ngram_range=(1,2), min_df = 0.05, max_df = 0.9)

feature_vect=tfidf_vect.fit_transform(patent['abstract'].values.astype('U'))
# Out:
# C:\Users\Beck\anaconda3\envs\2\lib\site-packages\sklearn\feature_extraction\text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ha', 'le', 'u', 'wa'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '

# %%
df=pd.DataFrame(feature_vect[0].T.todense(), index=tfidf_vect.get_feature_names(), columns=['TF-IDF'])
df=df.sort_values('TF-IDF', ascending=False)
print(df.head(25))
# Out:
#                      TF-IDF
# material           0.478456
# direction          0.476167
# disposed           0.470082
# plurality          0.373363
# having             0.352412
# includes           0.244487
# power              0.000000
# method             0.000000
# processing         0.000000
# process            0.000000
# present invention  0.000000
# method includes    0.000000
# present            0.000000
# position           0.000000
# nan                0.000000
# portion            0.000000
# provided           0.000000
# output             0.000000
# operation          0.000000
# network            0.000000
# provide            0.000000
# according          0.000000
# layer              0.000000
# structure          0.000000
# using              0.000000

# %%
feature_vect[:10]
# Out:
# <10x3 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>

# %%
patent['abstract'][0]
# Out:
# 'An agricultural implement having a rolling basket which includes a plurality of elongated members arranged in a substantially cylindrical shape. A stationary internal scraper is disposed in the inner chamber of the rolling basket and is adapted for breaking up a material from the inner chamber as the rolling basket is rotated around the major axis of rotation of the rolling basket. The internal scraper extends in an upward direction with respect to the major axis of rotation of the rolling basket with the upper edge of the internal scraper distally spaced away from and above the major axis of rotation of the rolling basket and with the lower edge of the internal scraper distally spaced away from and above the major axis of rotation of the rolling basket. The upper edge of the internal scraper is positioned above the lower edge.'

# %%
from keybert import KeyBERT
kw_model = KeyBERT()
kw_model.extract_keywords(patent['title'][0], keyphrase_ngram_range=(1, 1), stop_words='english', highlight=True)
# Out:
# Agricultural implement with a scraper internal to a rolling basket
# [('scraper', 0.5153),
#  ('rolling', 0.4206),
#  ('agricultural', 0.4138),
#  ('basket', 0.4097),
#  ('implement', 0.215)]

# %%
from sklearn.cluster import KMeans

# 5개 집합으로 군집화 수행. 예제를 위해 동일한 클러스터링 결과 도출용 random_state=0 
km_cluster = KMeans(n_clusters=9, max_iter=10000, random_state=0)
km_cluster.fit(feature_vect)
cluster_label = km_cluster.labels_
cluster_centers = km_cluster.cluster_centers_

# %%
patent['cluster_label']=cluster_label
patent.head(20)
# Out:
#           id        date                                              title  \
# 0   10881042  2021-01-05  Agricultural implement with a scraper internal...
# 1   10881043  2021-01-05  Method for increasing the load on driving rear...
# 2   10881044  2021-01-05              Planter with full tandem offset pivot
# 3   10881045  2021-01-05  System and method for prescribing fertilizer a...
# 4   10881046  2021-01-05  Agricultural liquid fertilizer and chemical de...
# 5   10881047  2021-01-05                 Robot mower with protruding blades
# 6   10881048  2021-01-05  Oscillating spreading arrangement for a combin...
# 7   10881049  2021-01-05                           Guiding device and baler
# 8   10881050  2021-01-05  Baler stuffer selectively operable to provide ...
# 9   10881051  2021-01-05  Fluid-cooled LED-based lighting methods and ap...
# 10  10881052  2021-01-05          Illuminating device for plant cultivation
# 11  10881053  2021-01-05   Cooling and condensation device for a greenhouse
# 12  10881054  2021-01-05  Fabrics containing a filler and methods of enh...
# 13  10881055  2021-01-05  Nutritionally and botanically enhanced mycelia...
# 14  10881056  2021-01-05              Bioreactor for in vitro plant culture
# 15  10881057  2021-01-05            Methods for hybrid corn seed production
# 16  10881058  2021-01-05    Breeding method for tetraploid Ricinus communis
# 17  10881059  2021-01-05                               Maize hybrid X95N793
# 18  10881060  2021-01-05                     Endophytes and related methods
# 19  10881061  2021-01-05                  Hybrid squash plant named tribute
#
#                                              abstract  cluster_label
# 0   An agricultural implement having a rolling bas...              4
# 1   A method for increasing the load on driving re...              4
# 2   An agricultural machine includes a frame havin...              0
# 3   A precision agriculture prescription system wh...              7
# 4   The present invention relates to a system that...              2
# 5   A robot mower includes a left cutter blade uni...              0
# 6   A combine harvester includes a straw chopper h...              0
# 7   An agricultural baler includes a frame, a pres...              4
# 8   An agricultural baler includes a baler chassis...              4
# 9   A fluid-cooled LED-based lighting fixture for ...              4
# 10  An illuminating device for plant cultivation t...              4
# 11  The invention relates to a cooling and condens...              2
# 12  Fabrics suitable for a wide variety of uses, i...              3
# 13  The invention is an important innovation in mu...              2
# 14  A bioreactor comprising: an upper container wi...              6
# 15  Methods for improving the efficiency and produ...              4
# 16  The present invention provides a breeding meth...              2
# 17  A novel maize variety designated X95N793 and s...              4
# 18  The present invention relates to a method for ...              2
# 19  A novel hybrid squash plant, designated Tribut...              2

# %%
patent[patent['cluster_label']==0].sort_values(by='title')
# Out:
#               id        date  \
# 251614  11134813  2021-10-05
# 192778  11075509  2021-07-27
# 251864  11135065  2021-10-05
# 295397  11178945  2021-11-23
# 45523   10926932  2021-02-23
# ...          ...         ...
# 185115  11067779  2021-07-20
# 229575  11112588  2021-09-07
# 325790  11209610  2021-12-28
# 54293   10935772  2021-03-02
# 174136  11056685  2021-07-06
#
#                                                     title  \
# 251614                           2-in-1 nail lamp station
# 192778                           2-shot molded vapor seal
# 251864                    3-D printed orthopedic implants
# 295397                     360 degree rotatable accessory
# 45523   3D flexible bag to be filled for biopharmaceut...
# ...                                                   ...
# 185115  Zoom lens and image pickup apparatus including...
# 229575                    Zoom lens and imaging apparatus
# 325790                    Zoom lens and imaging apparatus
# 54293                     Zoom lens and imaging apparatus
# 174136  “Flower-like” Li4Ti5O12-multiwalled carbon nan...
#
#                                                  abstract  cluster_label
# 251614  A nail lamp station includes a base lamp assem...              0
# 192778  An electrical box including a flange produced ...              0
# 251864  A spinal interbody implant is fabricated using...              0
# 295397  Provided is a 360-degree rotatable accessory. ...              0
# 45523   A 3-D flexible bag to be filled with a biophar...              0
# ...                                                   ...            ...
# 185115  Provided is a zoom lens including a plurality ...              0
# 229575  A zoom lens is constituted by, in order from t...              0
# 325790  The zoom lens consists of a positive first len...              0
# 54293   A zoom lens including a front group and a rear...              0
# 174136  A method of fabricating nanocomposite anode ma...              0
#
# [42890 rows x 5 columns]

# %%
patent[patent['cluster_label']==1].sort_values(by='title')
# Out:
#              id        date                                  title abstract  \
# 331274  D908803  2021-01-26                          100 sided die      NaN
# 335103  D912634  2021-03-09  18-key remote control with LED driver      NaN
# 338020  D915551  2021-04-06            2-in-1 water sprinkling can      NaN
# 335492  D913023  2021-03-16                           3 tier riser      NaN
# 353518  D931057  2021-09-21                      3 tier spice rack      NaN
# ...         ...         ...                                    ...      ...
# 343995  D921531  2021-06-08                                 Zipper      NaN
# 345234  D922770  2021-06-22                                 Zipper      NaN
# 334141  D911672  2021-03-02                        Zipper jumpsuit      NaN
# 330000  D907529  2021-01-12                          Zipper puller      NaN
# 358378  D935923  2021-11-16                               pH meter      NaN
#
#         cluster_label
# 331274              1
# 335103              1
# 338020              1
# 335492              1
# 353518              1
# ...               ...
# 343995              1
# 345234              1
# 334141              1
# 330000              1
# 358378              1
#
# [33192 rows x 5 columns]

# %%
patent[patent['cluster_label']==2].sort_values(by='title')
# Out:
#               id        date  \
# 289675  11173184  2021-11-16
# 259232  11142502  2021-10-12
# 151182  11033533  2021-06-15
# 214030  11096926  2021-08-24
# 264494  11147814  2021-10-19
# ...          ...         ...
# 79568   10961268  2021-03-30
# 297270  11180830  2021-11-23
# 273389  11156759  2021-10-26
# 215216  11098121  2021-08-24
# 132681  11014871  2021-05-25
#
#                                                     title  \
# 289675   Bacillus subtilis strain with probiotic activity
# 259232  (+)-morphinans as antagonists of Toll-like rec...
# 151182  (2R,4R)-5-(5′-chloro-2′-fluorobiphenyl-4-yl)-2...
# 214030  (3AR)-1,3A,8-trimethyl-1,2,3,3A,8,8A-hexahydro...
# 264494  (4-((3R,4R)-3-methoxytetrahydro-pyran-4-ylamin...
# ...                                                   ...
# 79568   β-nicotinate ester nucleotides and process for...
# 297270  γ, γ′ cobalt based alloys for additive manufac...
# 273389  μ-LED, μ-LED device, display and method for th...
# 215216         “Immune checkpoint intervention” in cancer
# 132681  “Multi-target” compounds with inhibitory activ...
#
#                                                  abstract  cluster_label
# 289675  The current invention concerns a new B. subtil...              2
# 259232  The present invention provides (+)-morphinans ...              2
# 151182  In one aspect, the invention relates to a comp...              2
# 214030  The invention includes an amount of (3aR)-1,3a...              2
# 264494  The invention provides a salt of a tetrahydrop...              2
# ...                                                   ...            ...
# 79568   The invention provides a compound of formula (...              2
# 297270  The invention relates to gamma, gamma'-cobalt-...              2
# 273389  The invention relates to various aspects of a ...              2
# 215216  The present invention relates to methods for i...              2
# 132681  The present invention relates to the design of...              2
#
# [21606 rows x 5 columns]

# %%
patent[patent['cluster_label']==3].sort_values(by='title')
# Out:
#               id        date  \
# 83085   10964817  2021-03-30
# 321977  11205750  2021-12-21
# 269120  11152471  2021-10-19
# 304258  11187871  2021-11-30
# 12658   10893796  2021-01-19
# ...          ...         ...
# 253437  11136651  2021-10-05
# 32704   10913994  2021-02-09
# 311868  11195548  2021-12-07
# 207856  11090716  2021-08-17
# 65582   10947161  2021-03-16
#
#                                                     title  \
# 83085   (110) surface orientation for reducing fermi-l...
# 321977  1S1R memory integrated structure with larger s...
# 269120  2-dimensional electron gas and 2-dimensional h...
# 304258  2D bi-pod flexure design, mount technique and ...
# 12658                2D multi-layer thickness measurement
# ...                                                   ...
# 253437  Zn-Mg alloy plated steel material having excel...
# 32704                   Zn—Al—Mg-based plated steel sheet
# 311868   Zoned block command to stream command translator
# 207856  ϵ-iron oxide type ferromagnetic powder and mag...
# 65582   “MXene” particulate material, production proce...
#
#                                                  abstract  cluster_label
# 83085   A device with improved device performance, and...              3
# 321977  The present disclosure provides a 1S1R memory ...              3
# 269120  Semiconductor devices including a first region...              3
# 304258  A bipod flexure mount couples an optic to a ba...              3
# 12658   A method for measuring layer thicknesses of a ...              3
# ...                                                   ...            ...
# 253437  Provided is a Zn—Mg alloy plated steel materia...              3
# 32704   A Zn—Al—Mg-based plated steel sheet has, an al...              3
# 311868  A method for performing an operation of a memo...              3
# 207856  Provided is an ε-iron oxide type ferromagnetic...              3
# 65582   A particulate material with a composition expr...              3
#
# [18100 rows x 5 columns]

# %%
from sklearn.cluster import KMeans

# 3개의 집합으로 군집화 
km_cluster = KMeans(n_clusters=4, max_iter=10000, random_state=0)
km_cluster.fit(feature_vect)
cluster_label = km_cluster.labels_


# 소속 클러스터를 cluster_label 컬럼으로 할당하고 cluster_label 값으로 정렬
patent['cluster_label'] = cluster_label
patent.sort_values(by='cluster_label')
# Out:
#               id        date  \
# 277100  11160495  2021-11-02
# 25602   10906835  2021-02-02
# 247345  11130509  2021-09-28
# 25585   10906818  2021-02-02
# 247328  11130492  2021-09-28
# ...          ...         ...
# 340661   D918193  2021-05-04
# 340660   D918192  2021-05-04
# 340659   D918191  2021-05-04
# 340673   D918205  2021-05-04
# 337892   D915423  2021-04-06
#
#                                                     title  \
# 277100                      Sleep apnea monitoring system
# 25602   Glass compositions, fiberizable glass composit...
# 247345  System and method for detecting a break in a r...
# 25585   Process for back-and-forth washing of adsorpti...
# 247328  Vehicle control device, vehicle control method...
# ...                                                   ...
# 340661                                  Electronic device
# 340660                                              Kiosk
# 340659                          Aircraft avionics console
# 340673                                              Mouse
# 337892  Display screen or portion thereof with graphic...
#
#                                                  abstract  cluster_label
# 277100  The present invention relates to a sleep apnea...              0
# 25602   The present invention relates generally to gla...              0
# 247345  The present invention refers to a method for d...              0
# 25585   The invention provides methods and systems for...              0
# 247328  A vehicle control device includes a recognizer...              0
# ...                                                   ...            ...
# 340661                                                NaN              3
# 340660                                                NaN              3
# 340659                                                NaN              3
# 340673                                                NaN              3
# 337892                                                NaN              3
#
# [363829 rows x 5 columns]

# %%
cluster_centers = km_cluster.cluster_centers_
print('cluster_centers shape :',cluster_centers.shape)
print(cluster_centers)
# Out:
# cluster_centers shape : (4, 83)
# [[2.90418346e-02 4.72873943e-02 1.42370260e-02 7.86268932e-03
#   1.17867013e-02 1.38635449e-02 1.19451608e-02 3.79804974e-03
#   8.81304159e-03 1.76930814e-02 3.31305173e-02 9.94935606e-02
#   6.97847232e-03 9.37388230e-03 1.28469946e-02 6.06249016e-03
#   3.97275321e-03 8.46202736e-03 1.00018600e-02 3.11721964e-03
#   7.94388779e-03 3.49118098e-02 8.32190141e-04 1.03215433e-02
#   7.14295681e-03 1.47793773e-02 6.26897774e-02 5.91728692e-03
#   4.42709265e-03 1.28470062e-02 2.99142912e-02 9.02288685e-03
#   1.15506584e-02 2.34769835e-02 1.11304636e-02 2.89675097e-02
#   4.47512585e-02 6.58979672e-03 1.28761866e-02 1.70765377e-02
#   3.02766882e-02 8.91019908e-03 2.23946961e-03 3.43546932e-01
#   1.26979385e-02 3.46436900e-02 1.35395604e-01 3.21505350e-03
#   1.51690698e-05 5.14848878e-03 5.74888435e-03 2.93661305e-03
#   1.07349502e-02 8.06474588e-03 9.08232540e-03 7.03305505e-03
#   2.41244913e-01 2.21111736e-01 4.13770894e-02 5.50650978e-03
#   2.02969564e-02 3.05922875e-02 9.73589142e-02 1.90613284e-03
#   2.58998176e-03 6.01424339e-03 2.02930827e-01 7.89761324e-03
#   1.36415854e-02 5.78516977e-03 6.03250954e-03 7.56409199e-03
#   7.22767248e-03 1.61584403e-02 9.39411476e-03 1.85933755e-02
#   1.26981852e-02 1.47105941e-02 6.38171557e-02 3.08459265e-02
#   9.45266084e-03 4.60813727e-02 7.61241863e-03]
#  [2.05454533e-02 2.65509474e-02 3.65422387e-02 4.73522698e-03
#   3.65124410e-02 6.17773361e-02 5.70438581e-03 3.00525562e-02
#   3.79019992e-02 2.25297229e-02 2.22316457e-02 2.62928815e-02
#   4.91187329e-02 1.41716603e-02 5.28433769e-02 2.42905232e-02
#   1.49020164e-02 1.05725842e-01 2.42442138e-02 2.17538385e-02
#   2.87655094e-02 1.13137600e-01 9.36624657e-03 1.74309142e-02
#   7.51675709e-03 3.68857002e-02 1.57312362e-02 3.10768336e-02
#   4.98444066e-03 1.61022256e-02 3.25310554e-02 5.45597224e-03
#   2.22017580e-02 1.10047685e-02 4.17500826e-03 1.77952063e-02
#   2.01404665e-02 5.76213044e-02 3.50730640e-02 5.32526197e-02
#   3.11646855e-02 6.26196986e-02 2.89567657e-02 5.95599050e-03
#   4.42944264e-03 6.77767113e-03 9.56634580e-02 2.27182000e-02
#   1.29800018e-05 4.51900717e-02 2.99675931e-02 2.75886349e-02
#   5.15384103e-02 1.00076439e-02 2.04139387e-02 3.30226225e-02
#   1.59560279e-02 2.76488639e-03 2.45427187e-02 3.03823532e-02
#   2.09895957e-02 4.41940630e-02 1.32958272e-02 1.80420664e-02
#   2.11419520e-02 2.55963752e-02 5.56947136e-03 2.57575533e-02
#   4.39980669e-02 3.36919421e-02 3.72072037e-02 6.12536933e-02
#   2.35966092e-02 9.71825899e-03 3.40097388e-03 5.86786531e-03
#   3.35949739e-02 4.93036280e-02 2.02060710e-02 2.74216656e-02
#   6.58320936e-02 4.10981791e-02 3.74067547e-02]
#  [6.89685389e-03 1.11011513e-02 2.13031973e-02 6.35566910e-02
#   5.02458895e-03 6.39824861e-03 6.90481786e-02 2.02790527e-02
#   8.21737739e-03 2.71457452e-02 2.68648314e-02 2.55187150e-02
#   4.83457188e-02 3.99019609e-02 1.30278734e-02 8.94652869e-03
#   3.06145455e-02 3.11475298e-03 7.81193739e-03 2.16511683e-03
#   2.64600859e-03 4.30937195e-02 1.48331086e-02 1.22147762e-02
#   5.45127734e-02 1.69763038e-02 9.22976005e-03 1.91891470e-02
#   4.91164794e-02 5.81358127e-02 1.54980443e-02 7.50432886e-02
#   8.13105480e-03 2.60955619e-02 4.15460919e-02 5.76676025e-02
#   7.35092889e-02 7.71261217e-03 2.73798634e-02 9.71769120e-02
#   4.38175217e-02 2.46142514e-03 5.96419673e-03 7.08239122e-03
#   1.05398799e-01 6.52170431e-02 3.08084717e-02 7.00995558e-03
#   1.90659673e-06 2.23614749e-03 7.61760726e-03 8.10531662e-03
#   4.80294977e-02 1.11533942e-01 4.41697636e-02 1.44676217e-02
#   1.15438827e-02 3.34616409e-03 1.15449378e-02 5.20553534e-03
#   1.06372743e-02 4.40135605e-02 8.97687864e-03 9.30236226e-03
#   5.24883238e-03 1.04387599e-02 5.23327862e-03 4.48475419e-03
#   1.62181110e-01 1.31821649e-02 8.98298199e-03 8.83686259e-03
#   1.78420624e-02 5.46942263e-02 5.76289103e-02 1.09493071e-01
#   5.70805291e-03 2.34613111e-02 1.08031773e-02 1.01929162e-02
#   5.21126481e-03 1.01035444e-02 4.93830209e-03]
#  [3.99009205e-06 0.00000000e+00 1.76058698e-05 0.00000000e+00
#   0.00000000e+00 1.07769971e-05 0.00000000e+00 0.00000000e+00
#   5.26731047e-05 0.00000000e+00 4.89856007e-06 6.70826392e-06
#   0.00000000e+00 0.00000000e+00 3.96462079e-06 1.37072384e-05
#   0.00000000e+00 2.35124004e-05 1.35199948e-05 0.00000000e+00
#   7.00625822e-06 6.87564364e-05 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 8.69469863e-06 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 3.48318746e-05 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   1.79257188e-06 0.00000000e+00 1.21689123e-05 4.54183668e-06
#   7.63717893e-06 5.49336611e-06 0.00000000e+00 5.49427171e-06
#   2.89031420e-06 0.00000000e+00 1.18369897e-05 4.74312804e-06
#   9.99909225e-01 2.47035490e-05 2.58336058e-05 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   5.01264643e-06 6.23461461e-06 0.00000000e+00 1.00884184e-05
#   1.68578638e-05 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   6.53085993e-06 0.00000000e+00 2.47786661e-06 1.28208778e-05
#   2.18125082e-05 0.00000000e+00 0.00000000e+00 2.25369280e-06
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   1.19892313e-05 0.00000000e+00 1.81787412e-05 3.29372013e-06
#   0.00000000e+00 7.90913803e-06 0.00000000e+00]]

# %%
# 군집별 top n 핵심단어, 그 단어의 중심 위치 상대값, 대상 파일명들을 반환함. 
def get_cluster_details(cluster_model, cluster_data, feature_names, clusters_num, top_n_features=10):
    cluster_details = {}
    
    # cluster_centers array 의 값이 큰 순으로 정렬된 index 값을 반환
    # 군집 중심점(centroid)별 할당된 word 피처들의 거리값이 큰 순으로 값을 구하기 위함.  
    centroid_feature_ordered_ind = cluster_model.cluster_centers_.argsort()[:,::-1]
    
    #개별 군집별로 iteration하면서 핵심단어, 그 단어의 중심 위치 상대값, 대상 파일명 입력
    for cluster_num in range(clusters_num):
        # 개별 군집별 정보를 담을 데이터 초기화. 
        cluster_details[cluster_num] = {}
        cluster_details[cluster_num]['cluster'] = cluster_num
        
        # cluster_centers_.argsort()[:,::-1] 로 구한 index 를 이용하여 top n 피처 단어를 구함. 
        top_feature_indexes = centroid_feature_ordered_ind[cluster_num, :top_n_features]
        top_features = [ feature_names[ind] for ind in top_feature_indexes ]
        
        # top_feature_indexes를 이용해 해당 피처 단어의 중심 위치 상댓값 구함 
        top_feature_values = cluster_model.cluster_centers_[cluster_num, top_feature_indexes].tolist()
        
        # cluster_details 딕셔너리 객체에 개별 군집별 핵심 단어와 중심위치 상대값, 그리고 해당 파일명 입력
        cluster_details[cluster_num]['top_features'] = top_features
        cluster_details[cluster_num]['top_features_value'] = top_feature_values
        title = cluster_data[cluster_data['cluster_label'] == cluster_num]['title']
        title = title.values.tolist()
        cluster_details[cluster_num]['title'] = title
        
    return cluster_details

# %%
def print_cluster_details(cluster_details):
    for cluster_num, cluster_detail in cluster_details.items():
        print('####### Cluster {0}'.format(cluster_num))
        print('Top features:', cluster_detail['top_features'])
        print('Reviews 제목 :',cluster_detail['title'][:7])
        print('==================================================')

# %%
feature_names = tfidf_vect.get_feature_names()

cluster_details = get_cluster_details(cluster_model=km_cluster, cluster_data=patent,\
                                  feature_names=feature_names, clusters_num=4, top_n_features=20 )
print_cluster_details(cluster_details)
# Out:
# ####### Cluster 0
# Top features: ['invention', 'present', 'present invention', 'relates', 'method', 'comprising', 'provides', 'use', 'disclosure', 'andor', 'using', 'having', 'process', 'device', 'material', 'comprises', 'used', 'provided', 'including', 'embodiment']
# Reviews 제목 : ['Agricultural liquid fertilizer and chemical delivery system and method of use', 'Cooling and condensation device for a greenhouse', 'Nutritionally and botanically enhanced mycelial mass', 'Breeding method for tetraploid Ricinus communis', 'Endophytes and related methods', 'Hybrid squash plant named tribute', 'Soybean variety 01072782']
# ==================================================
# ####### Cluster 1
# Top features: ['device', 'data', 'method', 'user', 'information', 'based', 'signal', 'image', 'includes', 'control', 'plurality', 'unit', 'configured', 'network', 'provided', 'second', 'using', 'communication', 'value', 'set']
# Reviews 제목 : ['Method for increasing the load on driving rear wheels of tractors during soil cultivation', 'System and method for prescribing fertilizer application rates for spatial distribution of a product', 'Fluid-cooled LED-based lighting methods and apparatus for controlled environment agriculture', 'Illuminating device for plant cultivation', 'Methods for hybrid corn seed production', 'Maize hybrid X95N793', 'Maize hybrid X13N205']
# ==================================================
# ####### Cluster 2
# Top features: ['second', 'portion', 'surface', 'layer', 'includes', 'end', 'having', 'body', 'material', 'assembly', 'element', 'ha', 'substrate', 'structure', 'direction', 'disposed', 'configured', 'plurality', 'position', 'provided']
# Reviews 제목 : ['Agricultural implement with a scraper internal to a rolling basket', 'Planter with full tandem offset pivot', 'Robot mower with protruding blades', 'Oscillating spreading arrangement for a combine harvester', 'Guiding device and baler', 'Baler stuffer selectively operable to provide partial stuffing strokes', 'Fabrics containing a filler and methods of enhancing crop growth']
# ==================================================
# ####### Cluster 3
# Top features: ['nan', 'device', 'communication', 'embodiment', 'operation', 'network', 'data', 'second', 'use', 'apparatus', 'provide', 'corresponding', 'described', 'response', 'include', 'time', 'method', 'based', 'processing', 'disclosure']
# Reviews 제목 : ['Neighbor awareness networking datapath—scheduling, scheduler rank, and pre-datapath operation triggering', 'Data link establishment method and apparatus', 'Interconnection method and system based on Wi-Fi aware protocol, and master device in NAN group', 'Data communication and resource management in hybrid infrastructure and neighbor awareness networking networks', 'Method system and device for obtaining location information using neighbor awareness networking, NAN', 'Communication apparatus, method of controlling communication apparatus, and non-transitory computer-readable storage medium', 'Cancelable NAN schedule indication']
# ==================================================

# %%
from keybert import KeyBERT
import collections.abc
from collections.abc import MutableMapping

# %%
def BERT(label):

    array_text = pd.DataFrame(patent[patent['cluster_label'] == label]['title']).to_numpy()

    bow = []
    from keybert import KeyBERT
    kw_extractor = KeyBERT('distilbert-base-nli-mean-tokens')
    for j in range(len(array_text)):
        keywords = kw_extractor.extract_keywords(array_text[j][0])
        bow.append(keywords)
    
    new_bow = []
    for i in range(0, len(bow)):
        for j in range(len(bow[i])):
            new_bow.append(bow[i][j])
            
            
    keyword = pd.DataFrame(new_bow, columns=['keyword', 'weight'])
    return keyword.groupby('keyword').agg('sum').sort_values('weight', ascending=False)

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 12165742084834304620,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 21795504128
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 4921901873796321828
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:0a:00.0, compute capability: 8.6"]

# %%
b0=BERT(0)

# %%
b0
# Out:
#                  weight
# keyword
# method        1470.4924
# methods        954.8962
# device         767.4540
# apparatus      502.9318
# compositions   476.2132
# ...                 ...
# bolus            0.1099
# aie              0.1040
# increases        0.0944
# let              0.0580
# ros              0.0515
#
# [16121 rows x 1 columns]

# %%
b0['cluster_label']=0

# %%
b0
# Out:
#                  weight  cluster_label
# keyword
# method        1470.4924              0
# methods        954.8962              0
# device         767.4540              0
# apparatus      502.9318              0
# compositions   476.2132              0
# ...                 ...            ...
# bolus            0.1099              0
# aie              0.1040              0
# increases        0.0944              0
# let              0.0580              0
# ros              0.0515              0
#
# [16121 rows x 2 columns]

# %%
b1=BERT(1)

# %%
b1
# Out:
#                weight
# keyword
# method     16669.5827
# device     14444.1257
# apparatus  11849.5854
# methods     5985.3599
# data        5642.5301
# ...               ...
# iort           0.1230
# pvt1           0.1198
# spoilers       0.1113
# midrib         0.1069
# downs          0.0770
#
# [29414 rows x 1 columns]

# %%
b1['cluster_label']=1
b1
# Out:
#                weight  cluster_label
# keyword
# method     16669.5827              1
# device     14444.1257              1
# apparatus  11849.5854              1
# methods     5985.3599              1
# data        5642.5301              1
# ...               ...            ...
# iort           0.1230              1
# pvt1           0.1198              1
# spoilers       0.1113              1
# midrib         0.1069              1
# downs          0.0770              1
#
# [29414 rows x 2 columns]

# %%
b2=BERT(2)

# %%
b2
# Out:
#                    weight
# keyword
# device         12150.3457
# method          8012.1922
# apparatus       6089.9360
# manufacturing   4704.8685
# semiconductor   4095.5949
# ...                   ...
# flowably           0.1590
# pyrazino           0.1517
# crocin             0.1394
# conscious          0.1067
# pyrrolo            0.0907
#
# [20010 rows x 1 columns]

# %%
b2['cluster_label']=2
b2
# Out:
#                    weight  cluster_label
# keyword
# device         12150.3457              2
# method          8012.1922              2
# apparatus       6089.9360              2
# manufacturing   4704.8685              2
# semiconductor   4095.5949              2
# ...                   ...            ...
# flowably           0.1590              2
# pyrazino           0.1517              2
# crocin             0.1394              2
# conscious          0.1067              2
# pyrrolo            0.0907              2
#
# [20010 rows x 2 columns]

# %%
final=pd.concat([b0,b1,b2])
final.head(20)
# Out:
#                    weight  cluster_label
# keyword
# method          1470.4924              0
# methods          954.8962              0
# device           767.4540              0
# apparatus        502.9318              0
# compositions     476.2132              0
# composition      424.0560              0
# treatment        414.5719              0
# compounds        351.8426              0
# thereof          296.7578              0
# preparation      293.9982              0
# manufacturing    290.4384              0
# use              280.4022              0
# cancer           277.8664              0
# inhibitors       276.4212              0
# pharmaceutical   248.0913              0
# soybean          246.9501              0
# antibodies       240.4238              0
# treating         240.1301              0
# uses             234.4366              0
# process          208.2897              0

# %%
final.to_csv('final.csv')
